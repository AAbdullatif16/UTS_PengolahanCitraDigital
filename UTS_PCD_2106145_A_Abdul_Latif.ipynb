# %% [markdown]
# <a href="https://colab.research.google.com/github/AAbdullatif16/UTS_PengolahanCitraDigital/blob/main/UTS_PCD_2106145_A_Abdul_Latif.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
from google.colab.patches import cv2_imshow
import cv2
import numpy as np
from skimage import io
import matplotlib.pyplot as plt

# %% [markdown]
# # **kode1**

# %%
# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Fungsi drive.mount('/content/drive') ini digunakan untuk menghubungkan dengan google drive.

# %%
# Path ke gambar di Google Drive
drive_image_path = '/content/drive/MyDrive/UTS PCD/saya.jpeg'

# Baca gambar dari Google Drive menggunakan skimage
image = io.imread(drive_image_path)
image_2 = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Gabungkan gambar
final_frame = np.hstack((image, image_2))
# Tampilkan gambar
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=450x300>

# %% [markdown]
# # **kode2**

# %%
print(image.size)
print(image.shape)
print(image.dtype)
# Out:
# 202500
# (300, 225, 3)
# uint8

# %% [markdown]
# # **kode3**

# %%
a = np.array([[1,2,2,2,10],[10,20,30,40,50]])
print(a)
print(a.ravel())
print(a.flatten())

plt.hist(a.ravel(), bins=50, range=[0, 50])
plt.show()
# Out:
# [[ 1  2  2  2 10]
#  [10 20 30 40 50]]
# [ 1  2  2  2 10 10 20 30 40 50]
# [ 1  2  2  2 10 10 20 30 40 50]

# %% [markdown]
# # **kode4**

# %%
plt.hist(image.ravel(), bins = 256, range = [0,256])
plt.show()

# %% [markdown]
# # **kode5**

# %%
color = ('b','g','r')
for i,col in enumerate(color):
  histogr = cv2.calcHist([image], [i], None, [256], [0,256])
  plt.plot(histogr, color = col)
  plt.xlim([0,256])
plt.show()

# %% [markdown]
# # **kode6**

# %%
color = ('b', 'g', 'r')
for i, col in enumerate(color):
    histogr = cv2.calcHist([image], [i], None, [4], [0, 256])
    plt.plot(histogr, color = col)
    plt.xlim([0, 4])
plt.show()

# %% [markdown]
# # **kode7

# %%
color = ('b','g','r')
for i,col in enumerate(color):
  histogr = cv2.calcHist([image], [i], None, [8], [0,256])
  plt.plot(histogr, color = col)
  plt.show()

# %% [markdown]
# # **kode8**

# %%
color = ('b', 'g', 'r')
for i, col in enumerate(color):
    histogram = cv2.calcHist([image], [i], None, [16], [0, 256])
    plt.plot(histogram, color=col)
plt.show()

# %% [markdown]
# # **kode9**

# %%
color = ('b','g','r')
for i,col in enumerate(color):
  histogr = cv2.calcHist([image], [i], None, [32], [0,256])
  plt.plot(histogr, color = col)
plt.show()

# %% [markdown]
# # **kode10**

# %%
b,g,r = cv2.split(image)
cv2_imshow(b)
# Out:
# <PIL.Image.Image image mode=L size=225x300>

# %% [markdown]
# # **kode11**

# %%
image = io.imread(drive_image_path)

#blue channel
bluech = image[:,:,0]
cv2_imshow(bluech)
# Out:
# <PIL.Image.Image image mode=L size=225x300>

# %% [markdown]
# # **kode12**

# %%
plt.hist(bluech.ravel(), 16, [0, 256], color='blue')
plt.xlabel('Bins 16')
plt.ylabel('Num of Pixel')
plt.show()

# %% [markdown]
# # **kode13**

# %%
plt.hist(bluech.ravel(), 8, [0, 256], color='blue')
plt.xlabel('Bins 32')
plt.ylabel('Num of Pixel')
plt.show()

# %% [markdown]
# # **kode14**

# %%
plt.hist(bluech.ravel(), 32, [0, 256], color='blue')
plt.xlabel('Bins 8')
plt.ylabel('Num of Pixel')
plt.show()

# %% [markdown]
# # **kode15**

# %%
plt.hist(bluech.ravel(), 256, [0, 256], color='blue')
plt.xlabel('Bins 256')
plt.ylabel('Num of Pixel')
plt.show()

# %% [markdown]
# # **kode16**

# %%
plt.hist(bluech.ravel(), 4, [0, 256], color='blue')
plt.xlabel('Bins 4')
plt.ylabel('Num of Pixel')
plt.show()

# %% [markdown]
# # **kode17**

# %%
#green channel
greench = image[:,:,1]
cv2_imshow(greench)
# Out:
# <PIL.Image.Image image mode=L size=225x300>

# %% [markdown]
# # **kode18**

# %%
plt.hist(bluech.ravel(), 8, [0, 256], color='green')
plt.xlabel('Bins 32')
plt.ylabel('Num of Pixel')
plt.show()

# %% [markdown]
# # **kode19**

# %%
plt.hist(bluech.ravel(), 4, [0, 256], color='green')
plt.xlabel('Bins 4')
plt.ylabel('Num of Pixel')
plt.show()

# %% [markdown]
# # **kode20**

# %%
plt.hist(bluech.ravel(), 16, [0, 256], color='green')
plt.xlabel('Bins 16')
plt.ylabel('Num of Pixel')
plt.show()

# %% [markdown]
# # **kode21**

# %%
plt.hist(bluech.ravel(), 32, [0, 256], color='green')
plt.xlabel('Bins 8')
plt.ylabel('Num of Pixel')
plt.show()

# %% [markdown]
# # **kode22**

# %%
plt.hist(bluech.ravel(), 256, [0, 256], color='green')
plt.xlabel('Bins 256')
plt.ylabel('Num of Pixel')
plt.show()

# %% [markdown]
# # **kode23**

# %%
#red channel

redch = image[:,:,2]
cv2_imshow(redch)
# Out:
# <PIL.Image.Image image mode=L size=225x300>

# %% [markdown]
# # **kode24**

# %%
plt.hist(redch.ravel(), 256, [0, 256], color='red')
plt.xlabel('Bins 256')
plt.ylabel('Num of Pixel')
plt.show()

# %% [markdown]
# # **kode25**

# %%
plt.hist(redch.ravel(), 32, [0, 256], color='red')
plt.xlabel('Bins 8')
plt.ylabel('Num of Pixel')
plt.show()

# %% [markdown]
# # **kode26**

# %%
plt.hist(redch.ravel(), 16, [0, 256], color='red')
plt.xlabel('Bins 16')
plt.ylabel('Num of Pixel')
# Out:
# Text(0, 0.5, 'Num of Pixel')

# %% [markdown]
# # **kode27**

# %%
plt.hist(redch.ravel(), 8, [0, 256], color='red')
plt.xlabel('Bins 32')
plt.ylabel('Num of Pixel')
# Out:
# Text(0, 0.5, 'Num of Pixel')

# %% [markdown]
# # **kode28**

# %%
plt.hist(redch.ravel(), 4, [0, 256], color='red')
plt.xlabel('Bins 4')
plt.ylabel('Num of Pixel')
# Out:
# Text(0, 0.5, 'Num of Pixel')

# %% [markdown]
# # **kode29**

# %%
gray_image = cv.cvtColor(image, cv.COLOR_BGR2GRAY)
cv2_imshow(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=225x300>

# %% [markdown]
# # **kode30**

# %%
plt.hist(gray_image.ravel(), bins = 256, range = [0,256])
plt.show()


print(gray_image.size)
print(gray_image.shape)
print(gray_image.dtype)
# Out:
# 67500
# (300, 225)
# uint8

# %% [markdown]
# # **kode31**

# %%
plt.hist(gray_image.ravel(), bins = 4, range = [0,256])
plt.show()


print(gray_image.size)
print(gray_image.shape)
print(gray_image.dtype)
# Out:
# 67500
# (300, 225)
# uint8

# %% [markdown]
# # **kode32**

# %%
invert_gray = 255 - gray_image
cv2_imshow(invert_gray)
# Out:
# <PIL.Image.Image image mode=L size=225x300>

# %% [markdown]
# # **kode33**

# %%
plt.hist(invert_gray.ravel(), bins = 256, range = [0,256])
plt.show()

# %% [markdown]
# # **kode34**

# %%
bright_image = (100.0/255)*gray_image + 100
cv2_imshow(bright_image)
# Out:
# <PIL.Image.Image image mode=L size=225x300>

# %% [markdown]
# # **kode35**

# %%
plt.hist(bright_image.ravel(), bins = 256, range = [0,256])
plt.show()

# %% [markdown]
# # **kode36**

# %%
darken_image = 255.0*(gray_image/255.0)**2
cv2_imshow(darken_image)
# Out:
# <PIL.Image.Image image mode=L size=225x300>

# %% [markdown]
# # **kode38**

# %%
plt.hist(darken_image.ravel(), bins = 256, range = [0,256])
plt.show()

# %% [markdown]
# # **kode39**

# %% [markdown]
# # **KESIMPULAN**
#
# ---
#
# **Terdapat beberapa kesalahan dalam kode nya, yang sudah diperbaiki:** </br>
# **Kode1:** Memperbaiki kode yang sebelumnya cv2.imshow menjadi cv2_imshow agar sesuai dengan kode yang ada di Google Colab.</br>
#
# **Kode4:** Dengan mengoreksi kesalahan  pada fungsi show() menjadi plt.show(), sekarang kode ini dapat menampilkan histogram dengan benar saat melakukan operasi pada array NumPy menggunakan Matplotlib.</br>
#
# **Kode6:** Setelah kesalahan penamaan pada variabel (histogr menjadi histogram) diperbaiki, dan penggunaan variabel saat plotting histogram disesuaikan, sehingga konsistensi kode terjaga dan dapat dijalankan dengan benar.</br>
#
# **Kode7:** Melalui koreksi kesalahan pada variabel warna (d menjadi b, b menjadi g), sekarang sesuai dengan format warna BGR pada OpenCV.</br>
#
# **Kode9:** Setelah melakukan perbaikan seperti mendefinisikan variabel histogram sebelum plt.plot() dan memperbaiki plt() dengan plt.show() sehingga dapat menampilkan histogram, dan kode nya dapat dijalankan untuk menampilkan histogram dengan warna yang sesuai yaitu (b, g, r).</br>
#
#  Setelah melakukan perbaikan pada beberapa kode, dapat disimpulkan bahwa histogram ini berfungsi sebagai alat visualisasi yang efektif untuk menganalisis distribusi intensitas piksel dalam gambar. Dengan perbaikan kesalahan seperti penggunaan fungsi dan variabel yang tepat, serta penyesuaian warna , sekarang kode-kode tersebut dapat dijalankan dengan benar. Kemudian visualisasi histogram yang dihasilkannya juga dapat memberikan wawasan yang akurat dan informatif mengenai karakteristik gambar, sehingga memudahkan analisis dan pemahaman terhadap distribusi nilai piksel yang ada dalam gambar tersebut.
